# %% [markdown]
# # My first Data Science Notebook

# %%
print("Hello, this is Anastasiya's data science environment")
# Out:
# Hello, this is Anastasiya's data science environment

# %%
#Let us explore basic markdown elements such as:
print('Headings,', 'Bold Text,', 'Italic Text.')
# Out:
# Headings, Bold Text, Italic Text.

# %% [markdown]
# # Headings
# # H1: This is a level 1 Heading
# ## H2: This is a level 2 Heading
# ### H3: This is a level 3 Heading
# #### H4: This is a level 4 Heading
# ##### H5: This is a level 5 Heading
# ###### H6: This is a level 6 Heading

# %% [markdown]
# # Bold Text
# #### You can create **bold** text by adding two asterisks or underscores before and after a word, phrase, or a sentence.

# %% [markdown]
# **Bold Text using asterisk.**
#
# __Bold Text using underscores"__

# %% [markdown]
# # Italic Text
# #### Using a single asterisk or underscore before and after a word
# *Text in italics using asterisk.*
#
# _Text in italic using undersore._

# %% [markdown]
# # Bold and Italic text
# #### You can create **bold** and *italic* text simultaneously by adding a three asterisks or underscores before and after a word, phrase or a sentence

# %% [markdown]
# ***Bold and Italic text using asterisks***
#
# ___Bold and Italic text using underscores___

# %% [markdown]
# # Insert links and images using Markdown
# #### You can create **hyperlink** in the following format.
# - ## [Name of the Link](Link url)
# - **Link url** is the web address of the url which will directed on clicking the link.
# - To display a clickable link without a name, enclose the link bacets.
# - <https://skills.network/>

# %% [markdown]
# [Skills Network](https://skills.network/)

# %% [markdown]
# # Images

# %% [markdown]
# #### Images can be rendered in the following format

# %% [markdown]
# Name of the image: ![alt text](PATH)

# %% [markdown]
# [Hyperlink to the company I work for](https://www.novartis.com/)

# %% [markdown]
# Novartis: ![The logo of the company I work for](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRNvdXSCKgNC156p69e6Xe7_wl1_E1ujv_D1w&s)

# %% [markdown]
# LOGO: ![This is the skills network logo](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png)

# %% [markdown]
# # Tables

# %% [markdown]
# #### To create tables use:
# - **hyphens** (----) for column headers
# - **pipes** | to separate each column
# - **Thext on a new line** to separate each row

# %% [markdown]
# | Country Name | Capital |
# |--------------| ------- |
# | Switzerland | Bern |
# | Netherlands | Amsterdam |
# | Austria | Vienna |
# | Poland | Warsaw |
# | Belarus | Minsk |
# | United States | Washington DC |
# #### a table is created with 1 heading row, 6 body rows and 2 columns

# %% [markdown]
# # List (Ordered and Unordered)
# ## **Unordered List**
# An unordered list is also reffered to as a **bulleted list**.
# You can create it this by adding dashes (-), asterisks (*), or plus signs (+) in front of line items.
#
# - First item
# - Second item
# - Third item
# - Fourth item

# %% [markdown]
# ## Welcome to Python programming
# Launcher: ![This is SN labels New Launcher](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Labs_V4/images/Launcher.png)

# %% [markdown]
# ## Hyperlink
# [Tools For Data Science](https://www.coursera.org/learn/open-source-tools-for-data-science/home )

# %% [markdown]
# ## Creating a table
#
# | Fruits | Quantity(Kg) | Price (in Rupee)|
# |------|------|------|
# | Apple | 2 | 500 |
# | Orange | 1 | 200 |
# | Mango | 3 | 1000 |
# | Grapes | 2 | 400 |

# %% [markdown]
# ## Creating an order list
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java
